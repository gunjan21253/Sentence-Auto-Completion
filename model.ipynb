# %%
pip install gensim
# Out:
# Requirement already satisfied: gensim in /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages (4.3.2)
# Requirement already satisfied: scipy>=1.7.0 in /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages (from gensim) (1.9.1)
# Requirement already satisfied: smart-open>=1.8.1 in /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages (from gensim) (6.4.0)
# Requirement already satisfied: numpy>=1.18.5 in /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages (from gensim) (1.24.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import sys
import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')

import pandas as pd
import nltk
from sklearn.feature_extraction.text import TfidfVectorizer
from gensim.models import LdaModel
from gensim.corpora import Dictionary
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk import ngrams
from nltk.corpus import reuters
from collections import defaultdict
from nltk import bigrams
from nltk.probability import FreqDist
from math import log
# Out:
# [nltk_data] Error loading stopwords: <urlopen error [Errno 54]
# [nltk_data]     Connection reset by peer>
# [nltk_data] Error loading punkt: <urlopen error [Errno 54] Connection
# [nltk_data]     reset by peer>
# [nltk_data] Error loading wordnet: <urlopen error [Errno 54]
# [nltk_data]     Connection reset by peer>

# %%
train_df = pd.read_csv("/Users/vidurgoel/Downloads/archive-3/train.csv")
train_df.head()
# Out:
#    ind         activity_label  \
# 0    4  Removing ice from car
# 1    8         Baking cookies
# 2    9         Baking cookies
# 3   12         Baking cookies
# 4   27      Getting a haircut
#
#                                                ctx_a  \
# 0  Then, the man writes over the snow covering th...
# 1  A female chef in white uniform shows a stack o...
# 2  A female chef in white uniform shows a stack o...
# 3  A tray of potatoes is loaded into the oven and...
# 4  The man in the center is demonstrating a hairs...
#
#                        ctx_b  \
# 0                       then
# 1                   the pans
# 2                    a knife
# 3       a large tray of meat
# 4  the man in the blue shirt
#
#                                                  ctx  \
# 0  Then, the man writes over the snow covering th...
# 1  A female chef in white uniform shows a stack o...
# 2  A female chef in white uniform shows a stack o...
# 3  A tray of potatoes is loaded into the oven and...
# 4  The man in the center is demonstrating a hairs...
#
#                                              endings  \
# 0  [', the man adds wax to the windshield and cut...
# 1  ['contain egg yolks and baking soda.'\n 'are t...
# 2  ['is seen moving on a board and cutting out it...
# 3  ['is placed onto a baked potato.'\n ', ls, and...
# 4  ['is standing on the sponge cutting the hair o...
#
#                    source_id  split split_type  label
# 0  activitynet~v_-1IBHYS3L-Y  train   indomain      3
# 1  activitynet~v_-2dxp-mv2zo  train   indomain      3
# 2  activitynet~v_-2dxp-mv2zo  train   indomain      3
# 3  activitynet~v_-2dxp-mv2zo  train   indomain      3
# 4  activitynet~v_-JqLjPz-07E  train   indomain      2

# %%
train_df.isnull().sum()
# Out:
# ind                   0
# activity_label        0
# ctx_a                 0
# ctx_b             25165
# ctx                   0
# endings               0
# source_id             0
# split                 0
# split_type            0
# label                 0
# dtype: int64

# %%
train_df.drop(['ind', 'source_id', 'split', 'split_type'], axis=1, inplace=True)
train_df.head()
# Out:
#           activity_label                                              ctx_a  \
# 0  Removing ice from car  Then, the man writes over the snow covering th...
# 1         Baking cookies  A female chef in white uniform shows a stack o...
# 2         Baking cookies  A female chef in white uniform shows a stack o...
# 3         Baking cookies  A tray of potatoes is loaded into the oven and...
# 4      Getting a haircut  The man in the center is demonstrating a hairs...
#
#                        ctx_b  \
# 0                       then
# 1                   the pans
# 2                    a knife
# 3       a large tray of meat
# 4  the man in the blue shirt
#
#                                                  ctx  \
# 0  Then, the man writes over the snow covering th...
# 1  A female chef in white uniform shows a stack o...
# 2  A female chef in white uniform shows a stack o...
# 3  A tray of potatoes is loaded into the oven and...
# 4  The man in the center is demonstrating a hairs...
#
#                                              endings  label
# 0  [', the man adds wax to the windshield and cut...      3
# 1  ['contain egg yolks and baking soda.'\n 'are t...      3
# 2  ['is seen moving on a board and cutting out it...      3
# 3  ['is placed onto a baked potato.'\n ', ls, and...      3
# 4  ['is standing on the sponge cutting the hair o...      2

# %%
a0_list = []
a1_list = []
a2_list = []
a3_list = []
# split endings column into 4 separate columns iterating over row and checking for quotes
for i in range(len(train_df)):
    count = 0
    str_0 = ''
    str_1 = ''
    str_2 = ''
    str_3 = ''

    flag_single_quote = 0
    flag_double_quote = 0

    for j in train_df['endings'][i]:


        if(j == '\'' and flag_single_quote == 1):
            flag_single_quote = 0
            count += 1
            continue

        if(j == '\"' and flag_double_quote == 1):
            flag_double_quote = 0
            count += 1
            continue
        
        if(j == '\'' and flag_single_quote == 0 and flag_double_quote != 1):
            flag_single_quote = 1
            count += 1

        if(flag_single_quote == 1 and flag_double_quote != 1):
            if(count == 1):
                str_0 += j
            elif(count == 3):
                str_1 += j
            elif(count == 5):
                str_2 += j
            elif(count == 7):
                str_3 += j

        if(j == '\"' and flag_double_quote == 0 and flag_single_quote != 1):
            flag_double_quote = 1
            count += 1

        if(flag_double_quote == 1 and flag_single_quote != 1):
            if(count == 1):
                str_0 += j
            elif(count == 3):
                str_1 += j
            elif(count == 5):
                str_2 += j
            elif(count == 7):
                str_3 += j

    a0_list.append(str_0)
    a1_list.append(str_1)
    a2_list.append(str_2)
    a3_list.append(str_3)

# %%
train_df.drop(['endings'], axis=1, inplace=True)

# insert the 4 new columns into the dataframe before the labels column
train_df.insert(4, 'A0', a0_list)
train_df.insert(5, 'A1', a1_list)
train_df.insert(6, 'A2', a2_list)
train_df.insert(7, 'A3', a3_list)

train_df.head()
# Out:
#           activity_label                                              ctx_a  \
# 0  Removing ice from car  Then, the man writes over the snow covering th...
# 1         Baking cookies  A female chef in white uniform shows a stack o...
# 2         Baking cookies  A female chef in white uniform shows a stack o...
# 3         Baking cookies  A tray of potatoes is loaded into the oven and...
# 4      Getting a haircut  The man in the center is demonstrating a hairs...
#
#                        ctx_b  \
# 0                       then
# 1                   the pans
# 2                    a knife
# 3       a large tray of meat
# 4  the man in the blue shirt
#
#                                                  ctx  \
# 0  Then, the man writes over the snow covering th...
# 1  A female chef in white uniform shows a stack o...
# 2  A female chef in white uniform shows a stack o...
# 3  A tray of potatoes is loaded into the oven and...
# 4  The man in the center is demonstrating a hairs...
#
#                                                   A0  \
# 0  ', the man adds wax to the windshield and cuts...
# 1                'contain egg yolks and baking soda.
# 2  'is seen moving on a board and cutting out its...
# 3                    'is placed onto a baked potato.
# 4  'is standing on the sponge cutting the hair of...
#
#                                                   A1  \
# 0  ', a person board a ski lift, while two men su...
# 1              'are then sprinkled with brown sugar.
# 2  'hits the peeled cheesecake, followed by slice...
# 3         ', ls, and pickles are placed in the oven.
# 4  'is doing the hairstyle with his hand and the ...
#
#                                                   A2  \
# 0  ', the man puts on a christmas coat, knitted w...
# 1          'are placed in a strainer on the counter.
# 2  'etches a shape into the inside of the baked p...
# 3                          'is poured into a midden.
# 4               'sits on the chair next to the sink.
#
#                                                   A3  label
# 0  ', the man continues removing the snow on his ...      3
# 1  'are filled with pastries and loaded into the ...      3
# 2  'is used to cut cylinder shaped dough into rou...      3
# 3  'is prepared then it is removed from the oven ...      3
# 4                        'is being shown eye to eye.      2

# %%
right_end=[]
for i in range(len(train_df)):
    if(train_df['label'][i]==0):
        right_end.append(a0_list[i])
    if(train_df['label'][i]==1):
        right_end.append(a1_list[i])
    if(train_df['label'][i]==2):
        right_end.append(a2_list[i])
    if(train_df['label'][i]==3):
        right_end.append(a3_list[i])

# %%
modified_array = [s[1:] for s in right_end]

# %%
train_df.insert(8,'Ans',modified_array)
train_df.head()
# Out:
#           activity_label                                              ctx_a  \
# 0  Removing ice from car  Then, the man writes over the snow covering th...
# 1         Baking cookies  A female chef in white uniform shows a stack o...
# 2         Baking cookies  A female chef in white uniform shows a stack o...
# 3         Baking cookies  A tray of potatoes is loaded into the oven and...
# 4      Getting a haircut  The man in the center is demonstrating a hairs...
#
#                        ctx_b  \
# 0                       then
# 1                   the pans
# 2                    a knife
# 3       a large tray of meat
# 4  the man in the blue shirt
#
#                                                  ctx  \
# 0  Then, the man writes over the snow covering th...
# 1  A female chef in white uniform shows a stack o...
# 2  A female chef in white uniform shows a stack o...
# 3  A tray of potatoes is loaded into the oven and...
# 4  The man in the center is demonstrating a hairs...
#
#                                                   A0  \
# 0  ', the man adds wax to the windshield and cuts...
# 1                'contain egg yolks and baking soda.
# 2  'is seen moving on a board and cutting out its...
# 3                    'is placed onto a baked potato.
# 4  'is standing on the sponge cutting the hair of...
#
#                                                   A1  \
# 0  ', a person board a ski lift, while two men su...
# 1              'are then sprinkled with brown sugar.
# 2  'hits the peeled cheesecake, followed by slice...
# 3         ', ls, and pickles are placed in the oven.
# 4  'is doing the hairstyle with his hand and the ...
#
#                                                   A2  \
# 0  ', the man puts on a christmas coat, knitted w...
# 1          'are placed in a strainer on the counter.
# 2  'etches a shape into the inside of the baked p...
# 3                          'is poured into a midden.
# 4               'sits on the chair next to the sink.
#
#                                                   A3  \
# 0  ', the man continues removing the snow on his ...
# 1  'are filled with pastries and loaded into the ...
# 2  'is used to cut cylinder shaped dough into rou...
# 3  'is prepared then it is removed from the oven ...
# 4                        'is being shown eye to eye.
#
#                                                  Ans  label
# 0  , the man continues removing the snow on his car.      3
# 1  are filled with pastries and loaded into the o...      3
# 2  is used to cut cylinder shaped dough into rounds.      3
# 3  is prepared then it is removed from the oven b...      3
# 4                sits on the chair next to the sink.      2

# %%
train_df.drop(['ctx_a', 'ctx_b', 'A0', 'A1','A2','A3','label'], axis=1, inplace=True)
train_df.head()
# Out:
#           activity_label                                                ctx  \
# 0  Removing ice from car  Then, the man writes over the snow covering th...
# 1         Baking cookies  A female chef in white uniform shows a stack o...
# 2         Baking cookies  A female chef in white uniform shows a stack o...
# 3         Baking cookies  A tray of potatoes is loaded into the oven and...
# 4      Getting a haircut  The man in the center is demonstrating a hairs...
#
#                                                  Ans
# 0  , the man continues removing the snow on his car.
# 1  are filled with pastries and loaded into the o...
# 2  is used to cut cylinder shaped dough into rounds.
# 3  is prepared then it is removed from the oven b...
# 4                sits on the chair next to the sink.

# %%
copy_train_df=train_df

# %%
corpus=[]
for i in range(len(train_df)):
    corpus.append(train_df['ctx'][i]+' '+train_df['Ans'][i])
print(corpus[99])
print(train_df['ctx'][99])
# Out:
# A cheer-leading team begins to hold up posters as their mascot runs behind them. they then begin to do a routine and some of the girls run with streamers as the rest of them hold up the girls for their stunt.
# A cheer-leading team begins to hold up posters as their mascot runs behind them. they

# %%
train_df.insert(3,'Sentence',corpus)
train_df.head()
# Out:
#           activity_label                                                ctx  \
# 0  Removing ice from car  Then, the man writes over the snow covering th...
# 1         Baking cookies  A female chef in white uniform shows a stack o...
# 2         Baking cookies  A female chef in white uniform shows a stack o...
# 3         Baking cookies  A tray of potatoes is loaded into the oven and...
# 4      Getting a haircut  The man in the center is demonstrating a hairs...
#
#                                                  Ans  \
# 0  , the man continues removing the snow on his car.
# 1  are filled with pastries and loaded into the o...
# 2  is used to cut cylinder shaped dough into rounds.
# 3  is prepared then it is removed from the oven b...
# 4                sits on the chair next to the sink.
#
#                                             Sentence
# 0  Then, the man writes over the snow covering th...
# 1  A female chef in white uniform shows a stack o...
# 2  A female chef in white uniform shows a stack o...
# 3  A tray of potatoes is loaded into the oven and...
# 4  The man in the center is demonstrating a hairs...

# %%
train_df.drop(['ctx', 'Ans'], axis=1, inplace=True)
train_df.head()
# Out:
#           activity_label                                           Sentence
# 0  Removing ice from car  Then, the man writes over the snow covering th...
# 1         Baking cookies  A female chef in white uniform shows a stack o...
# 2         Baking cookies  A female chef in white uniform shows a stack o...
# 3         Baking cookies  A tray of potatoes is loaded into the oven and...
# 4      Getting a haircut  The man in the center is demonstrating a hairs...

# %%
num_unique_labels = train_df['activity_label'].nunique()
print(num_unique_labels)
print(len(train_df))
# Out:
# 178
# 39905

# %%
# dictionary_containing_sentence_of_each_activity_label
train_df.head()
dictionary_containing_sentence_of_each_activity_label={}
for i in range(len(train_df)):
    if train_df.loc[i,'activity_label'] in dictionary_containing_sentence_of_each_activity_label:
        dictionary_containing_sentence_of_each_activity_label[train_df.loc[i,'activity_label']].append(train_df.loc[i,'Sentence'])
    else:
        dictionary_containing_sentence_of_each_activity_label[train_df.loc[i,'activity_label']]=[]
        dictionary_containing_sentence_of_each_activity_label[train_df.loc[i,'activity_label']].append(train_df.loc[i,'Sentence'])
print(len(dictionary_containing_sentence_of_each_activity_label))
print(dictionary_containing_sentence_of_each_activity_label['Baking cookies'])
train_df.head()
# print(dictionary_containing_sentence_of_each_activity_label)
# Out:
# 178
# ['A female chef in white uniform shows a stack of baking pans in a large kitchen presenting them. the pans are filled with pastries and loaded into the oven.', 'A female chef in white uniform shows a stack of baking pans in a large kitchen presenting them. The pans are filled with pastries and loaded into the oven. a knife is used to cut cylinder shaped dough into rounds.', 'A tray of potatoes is loaded into the oven and removed. A large tray of cake is flipped over and placed on counter. a large tray of meat is prepared then it is removed from the oven by a helper when done.', 'The woman is talking again and the next cookie she is shown making is called "cookie snowballs" and it shows all the ingredients needed, a list on how long to cook it for, and she\'s demonstrating step by step until it\'s all baked and on a plate next to the other cookies. the video ends with more pictures of other cookies she wasn\'t shown making, then to a green screen that has white words that include a message to go to their website if you want to see more videos of their cookie recipes.', '. a girl wearing an orange hoodie and a girl wearing a black blouse enter a home and go into the kitchen.', 'A girl wearing an orange hoodie and a girl wearing a black blouse enter a home and go into the kitchen. the girls are preparing to bake cookies.', 'A girl wearing an orange hoodie and a girl wearing a black blouse enter a home and go into the kitchen. The girls are preparing to bake cookies. the cell phone rings and both girls get excited.', 'The girl in the orange hoodie squeezes a bar of butter and it falls to the floor and slams the door shut. the girl in the black blouse turns and walks away dejected.', 'A woman is seen walking into frame while speaking to the camera and putting her face in cream. the woman then rubs the cream on her face while still speaking to the camera.', 'A man sits on front a bowl, then a woman shows cookie dough in bowls, then review a cookbook. then , the woman make dough balls and putsion a baking pan, also a teen makes dough balls and puts in baking pan.', 'Then, the woman make dough balls and putsion a baking pan, also a teen makes dough balls and puts in baking pan. after , the man put the cookies in the oven.', 'A blender is then put on the counter and the lever is pulled down followed by a tea bag being placed in a cup. The lady then moves to a counter and adds a piece of baking paper over two large racks. she then grabs the boiling hot water and pours it into the mug.', 'The lady then moves to a counter and adds a piece of baking paper over two large racks. She then grabs the boiling hot water and pours it into the mug. she returns back to the counter and begins placing rolls of cookie dough on the racks.', "She then grabs the boiling hot water and pours it into the mug. She returns back to the counter and begins placing rolls of cookie dough on the racks. its finally time for the cookies to be in put in the oven and she sets the timer on her phone so she won't burn them.", "Its finally time for the cookies to be in put in the oven and she sets the timer on her phone so she won't burn them. after the time is up, she takes them out of the oven adds one on a plate and takes it to a girl down the hall.", 'She pulls out the panels as well as putting sunglasses on and presents a pan of objects to the camera. she continues speaking to the camera and pulls the objects out to present baked cookies.', 'The person is shown mixing the ingredients. the person rolls the dough and cuts it into little pieces and flattens the tiny balls out using their hands.', 'The person rolls the dough and cuts it into little pieces and flattens the tiny balls out using their hands. the person uses a fork to put lines in the dough.', 'The person rolls the dough and cuts it into little pieces and flattens the tiny balls out using their hands. The person uses a fork to put lines in the dough. then the person puts the cookies on a baking sheet in a pan ...
#           activity_label                                           Sentence
# 0  Removing ice from car  Then, the man writes over the snow covering th...
# 1         Baking cookies  A female chef in white uniform shows a stack o...
# 2         Baking cookies  A female chef in white uniform shows a stack o...
# 3         Baking cookies  A tray of potatoes is loaded into the oven and...
# 4      Getting a haircut  The man in the center is demonstrating a hairs...

# %%
X = train_df['Sentence']

m=""

for i in X:
    m=m+" "+i
print(m[0:1000])
corpus=m

stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()
set1={'[header]', '[title]', '[step]', '[substep]', 'header', 'title', 'step', 'substep'}
tokens = nltk.word_tokenize(corpus.lower())
filtered_documents = []
for word in tokens:
    if word=='.':
        filtered_documents.append('<e>')
        # filtered_documents.append('<s>')
        continue
    if word.isalnum() and word not in set1:
        filtered_documents.append(word)
# filtered_documents = [lemmatizer.lemmatize(word) for word in tokens if word.isalnum() and word not in set1]
tokens=filtered_documents

# Create unigrams, bigrams, and trigrams
unigrams = list(ngrams(tokens, 1))
bigrams = list(ngrams(tokens, 2))
trigrams = list(ngrams(tokens, 3))
quadgrams = list(ngrams(tokens, 4))
pentagrams = list(ngrams(tokens, 5))
hexagrams = list(ngrams(tokens, 6))

# Calculate frequencies for each n-gram with Laplace smoothing
V = len(set(tokens))  # Vocabulary size
unigram_freq = nltk.FreqDist(unigrams)
bigram_freq = nltk.FreqDist(bigrams)
trigram_freq = nltk.FreqDist(trigrams)
quadgrams_freq = nltk.FreqDist(quadgrams)
pentagrams_freq = nltk.FreqDist(pentagrams)
hexagrams_freq = nltk.FreqDist(hexagrams)

n_gram_array=[]
n_gram_array.append(unigram_freq)
n_gram_array.append(bigram_freq)
n_gram_array.append(trigram_freq)
n_gram_array.append(quadgrams_freq)
n_gram_array.append(pentagrams_freq)
n_gram_array.append(hexagrams_freq)


def laplace_smoothed_prob(ngram, ngram_freq, n):
    # Apply Laplace smoothing to calculate probability
    numerator = ngram_freq[ngram] + 1
    denominator = ngram_freq[ngram[:-1]] + V
    return n * numerator / denominator

# Function to predict the next word(s) with Laplace smoothing
def predict_next_word(input_text, ngram_model, n):
    tokens = nltk.word_tokenize(input_text.lower())
    filtered_documents = [lemmatizer.lemmatize(word) for word in tokens if word.isalnum() and word not in set1]
    input_tokens=filtered_documents
    
    # Replace out-of-vocabulary words with low probability words from the corpus
    replaced_tokens = []
    for i in range(len(input_tokens)):
        if input_tokens[i] not in set(tokens):
            low_prob_words = sorted(set(tokens), key=lambda x: laplace_smoothed_prob((x,), unigram_freq, 1))
            replaced_tokens.append(low_prob_words[0] if low_prob_words else None)
        else:
            replaced_tokens.append(input_tokens[i])
    
    # Extend the training corpus with the replaced tokens
    tokens.extend(replaced_tokens)
    
    # Filter n-grams that start with the updated input_ngram
    input_ngram = tuple(input_tokens[-n + 1:])
    candidate_ngrams = [ngram for ngram in ngram_model if ngram[:n - 1] == input_ngram]
    
    if not candidate_ngrams:
        return None
    
    # Select the most likely next word(s) based on smoothed probability
    next_ngram = max(candidate_ngrams, key=lambda x: laplace_smoothed_prob(x, ngram_model, n))
    
    return next_ngram[n - 1]
# Out:
#  Then, the man writes over the snow covering the window of a car, and a woman wearing winter clothes smiles. then , the man continues removing the snow on his car. A female chef in white uniform shows a stack of baking pans in a large kitchen presenting them. the pans are filled with pastries and loaded into the oven. A female chef in white uniform shows a stack of baking pans in a large kitchen presenting them. The pans are filled with pastries and loaded into the oven. a knife is used to cut cylinder shaped dough into rounds. A tray of potatoes is loaded into the oven and removed. A large tray of cake is flipped over and placed on counter. a large tray of meat is prepared then it is removed from the oven by a helper when done. The man in the center is demonstrating a hairstyle on the person wearing the blue shirt. the man in the blue shirt sits on the chair next to the sink. The man in the blue shirt sits on the chair next to the sink. The other man begins washing his hair. he scrubs

# %% [markdown]
# Predicting the end of the sentence

# %%
def wordgen(words):
    empty=[]
    for i in range(len(words[-1])):
        input_text=words[-1][i]
        for i in range(1,6):
            text=predict_next_word(input_text, n_gram_array[i], i)
            if(text != None):
                empty.append(input_text +' '+text)
    set1=set(empty)
    list1=list(set1)
    words.append(list1)
    return words

# %%
import random
def sentences_generator(input_text):
    words=[]
    empty=[]

    for i in range(1,6):
        text=predict_next_word(input_text, n_gram_array[i], i)
        if(text != None):
            # print(text)
            empty.append(input_text+' '+text)
    additional_words_list=["the", "a", "with", "and", "which", "that", "is", "was", "will", "should"]
    if(len(empty)==0):
        selected_list = random.sample(additional_words_list, 4)
        for i in selected_list:
            empty.append(input_text+' '+i)
    words.append(empty)
    sentence_list = []
    sentence_ended = []
    for i in range(5):
        # print(words)
        words=wordgen(words)
        # print(words)
        # print("Length of words", len(words))
        # print(len(words[0]))
        for j in words:
            for k in j:
                # sentence_list.append(k)
                if k not in sentence_list:
                    sentence_list.append(k)
                
                # if there is '<e>' in k then remove k from words
                if '<e>' in k:
                    sentence_ended.append(k)
                    # j.remove(k)
    a7=sentence_list+sentence_ended
    return a7



input_text="Dark matter gathers around"
sentence_list=sentences_generator(input_text)
print(sentence_list)
# Out:
# ['Dark matter gathers around <e>', 'Dark matter gathers around as', 'Dark matter gathers around as group', 'Dark matter gathers around as man', 'Dark matter gathers around <e> formado', 'Dark matter gathers around as pot', 'Dark matter gathers around as pot to', 'Dark matter gathers around as pot of', 'Dark matter gathers around <e> formado sozo', 'Dark matter gathers around as man standing', 'Dark matter gathers around as group of', 'Dark matter gathers around as man is', 'Dark matter gathers around as pot of people', 'Dark matter gathers around as pot of water', 'Dark matter gathers around as pot to see', 'Dark matter gathers around as pot to boil', 'Dark matter gathers around as man is seen', 'Dark matter gathers around as man standing in', 'Dark matter gathers around as group of people', 'Dark matter gathers around <e> formado sozo appears', 'Dark matter gathers around as pot to the', 'Dark matter gathers around as man is standing', 'Dark matter gathers around as pot to the camera', 'Dark matter gathers around as pot of people are', 'Dark matter gathers around as pot to see the', 'Dark matter gathers around as pot to boil <e>', 'Dark matter gathers around as man is seen speaking', 'Dark matter gathers around as group of people are', 'Dark matter gathers around as pot to see if', 'Dark matter gathers around as pot of water and', 'Dark matter gathers around as man is standing in', 'Dark matter gathers around as pot to boil water', 'Dark matter gathers around as man standing in front', 'Dark matter gathers around as pot of water to', 'Dark matter gathers around as pot to boil the', 'Dark matter gathers around as pot to see a', 'Dark matter gathers around as pot of water <e>', 'Dark matter gathers around <e> formado sozo appears on', 'Dark matter gathers around as man is standing in front', 'Dark matter gathers around as man is seen speaking to', 'Dark matter gathers around as pot to boil <e> formado', 'Dark matter gathers around as pot of water and turns', 'Dark matter gathers around as pot to see the ending', 'Dark matter gathers around as pot to see the net', 'Dark matter gathers around <e> formado sozo appears on a', 'Dark matter gathers around as pot of water to a', 'Dark matter gathers around as pot of people are seen', 'Dark matter gathers around as group of people are shown', 'Dark matter gathers around as group of people are seen', 'Dark matter gathers around as pot to see if there', 'Dark matter gathers around as pot of water <e> formado', 'Dark matter gathers around as pot of water to the', 'Dark matter gathers around as pot of water and bring', 'Dark matter gathers around as pot to boil water to', 'Dark matter gathers around as pot to boil water <e>', 'Dark matter gathers around as pot to see if you', 'Dark matter gathers around as pot of water and soap', 'Dark matter gathers around as pot to see a lot', 'Dark matter gathers around as man standing in front of', 'Dark matter gathers around as pot to see the camera', 'Dark matter gathers around as pot to see a man', 'Dark matter gathers around as pot to boil the camera', 'Dark matter gathers around as pot of water and leads', 'Dark matter gathers around <e> formado sozo appears on the', 'Dark matter gathers around as pot to boil the water', 'Dark matter gathers around as pot to the camera <e>', 'Dark matter gathers around as pot to see the pasta', 'Dark matter gathers around as pot of people are shown', 'Dark matter gathers around <e>', 'Dark matter gathers around <e> formado', 'Dark matter gathers around <e>', 'Dark matter gathers around <e> formado', 'Dark matter gathers around <e> formado sozo', 'Dark matter gathers around <e>', 'Dark matter gathers around <e> formado', 'Dark matter gathers around <e> formado sozo', 'Dark matter gathers around <e> formado sozo appears', 'Dark matter gathers around <e>', 'Dark matter gathers around <e> formado', 'Dark matter gathers around <e> formado sozo', 'Dark matter gathers around <e> formado sozo appears', 'Dark matter gather ...

# %% [markdown]
# Ranking and printing the top 15 predictions

# %%
# Calculate average PMI for each sentence
import nltk
from nltk import bigrams
from nltk.probability import FreqDist
from math import log


def printing(corpus,sentence_list):
    tokens = nltk.word_tokenize(corpus.lower())
    filtered_documents = [word for word in tokens if word.isalnum()]
    corpus_bigram_list = list(bigrams(filtered_documents))

    words_freq_distr = FreqDist(filtered_documents)
    bigrams_freq_distr = FreqDist(corpus_bigram_list)
    pmi_scores_of_all_sentences_a1 = []
    for s in sentence_list:
        s_tokens = nltk.word_tokenize(s.lower())
        s_bigrams = list(bigrams(s_tokens))
        total_pmi_score=0
        for w1,w2 in s_bigrams:
            
            tot=len(filtered_documents)
            prob_x = words_freq_distr[w1] / tot
            prob_y = words_freq_distr[w2]  / tot

            if (w1, w2) in bigrams_freq_distr:
                prob_x_and_y = bigram_freq[(w1, w2)] / len(corpus_bigram_list)
            else:
                prob_x_and_y = 0.0

            if prob_x_and_y != 0.0:
                total_pmi_score+=log(prob_x_and_y/ (prob_x * prob_y), 2)

        if len(s_bigrams) > 0:
            pmi_mean = total_pmi_score / len(s_bigrams)
        else:
            pmi_mean = 0.0
        pmi_scores_of_all_sentences_a1.append(pmi_mean)
    # a1=sentence_list+sentence_ended
    # print(type(a1))
    # pmi_scores_of_all_sentence_a1 = printing(corpus,a1)
    sorted_pmi_scores_sentence_a1 = sorted(zip(sentence_list, pmi_scores_of_all_sentences_a1), key=lambda x: x[1], reverse=True)

    main_list1={}
    main_list2={}
    for rank, (s, pmi) in enumerate(sorted_pmi_scores_sentence_a1, start=1):
        if s.endswith(" <e>"):
            main_list1[s]=pmi
        else:
            main_list2[s]=pmi
    print("Printing the top ranked sentences according to the Mean PMI scores(sentences ended with <e>):")
    num=1
    for i in main_list1:
        print(f"Rank number {num}: {i} (Mean PMI score: {main_list1[i]})")
        num+=1
        # if(num>10):
        #     break
    num=1
    print()
    print()
    print("Printing the top ranked sentences according to the Mean PMI scores(sentences not ended with <e>):")
    for i in main_list2:
        print(f"Rank number {num}: {i} (Mean PMI score: {main_list2[i]})")
        num+=1
        # if(num>10):
        #     break
        
printing(corpus,sentence_list)
# Out:
# Printing the top ranked sentences according to the Mean PMI scores(sentences ended with <e>):
# Rank number 1: Dark matter gathers around as pot of water <e> (Mean PMI score: 1.0105366317728843)
# Rank number 2: Dark matter gathers around as pot to boil water <e> (Mean PMI score: 0.9772780159187804)
# Rank number 3: Dark matter gathers around <e> (Mean PMI score: 0.8345536507440986)
# Rank number 4: Dark matter gathers around as pot to the camera <e> (Mean PMI score: 0.7982805382562234)
# Rank number 5: Dark matter gathers around as pot to boil <e> (Mean PMI score: 0.6687697614959551)
#
#
# Printing the top ranked sentences according to the Mean PMI scores(sentences not ended with <e>):
# Rank number 1: Dark matter gathers around <e> formado sozo appears (Mean PMI score: 4.268440239223049)
# Rank number 2: Dark matter gathers around <e> formado sozo appears on (Mean PMI score: 4.257055850513522)
# Rank number 3: Dark matter gathers around <e> formado sozo appears on the (Mean PMI score: 4.111744992970708)
# Rank number 4: Dark matter gathers around <e> formado sozo appears on a (Mean PMI score: 4.063516855196323)
# Rank number 5: Dark matter gathers around <e> formado sozo (Mean PMI score: 3.2810890950140337)
# Rank number 6: Dark matter gathers around as man is seen speaking to (Mean PMI score: 3.0660235035688435)
# Rank number 7: Dark matter gathers around as man is seen speaking (Mean PMI score: 2.9285051792137127)
# Rank number 8: Dark matter gathers around as man is standing in front (Mean PMI score: 2.6596515738963658)
# Rank number 9: Dark matter gathers around as man standing in front of (Mean PMI score: 2.477200097507429)
# Rank number 10: Dark matter gathers around as group of people are shown (Mean PMI score: 2.419082670699824)
# Rank number 11: Dark matter gathers around as group of people are seen (Mean PMI score: 2.3551296865992706)
# Rank number 12: Dark matter gathers around as man is standing in (Mean PMI score: 2.317426161646361)
# Rank number 13: Dark matter gathers around as pot of people are shown (Mean PMI score: 2.308885490947287)
# Rank number 14: Dark matter gathers around as pot of people are seen (Mean PMI score: 2.244932506846733)
# Rank number 15: Dark matter gathers around as man is seen (Mean PMI score: 2.139912361449106)
# Rank number 16: Dark matter gathers around as man standing in front (Mean PMI score: 2.13968872316747)
# Rank number 17: Dark matter gathers around as man is standing (Mean PMI score: 2.0279705678821105)
# Rank number 18: Dark matter gathers around as group of people are (Mean PMI score: 2.0255608171445036)
# Rank number 19: Dark matter gathers around as pot of people are (Mean PMI score: 1.901588989922899)
# Rank number 20: Dark matter gathers around as pot of water and leads (Mean PMI score: 1.8604429869881638)
# Rank number 21: Dark matter gathers around as pot to see if you (Mean PMI score: 1.7681601382192507)
# Rank number 22: Dark matter gathers around as man standing in (Mean PMI score: 1.6742935590633368)
# Rank number 23: Dark matter gathers around as pot to see if there (Mean PMI score: 1.6669872733147006)
# Rank number 24: Dark matter gathers around as group of people (Mean PMI score: 1.6318063960004863)
# Rank number 25: Dark matter gathers around as pot of water and bring (Mean PMI score: 1.609908012047765)
# Rank number 26: Dark matter gathers around as pot of water and turns (Mean PMI score: 1.6005740505543984)
# Rank number 27: Dark matter gathers around as pot to see a lot (Mean PMI score: 1.5455272390993666)
# Rank number 28: Dark matter gathers around as man is (Mean PMI score: 1.5408478346438466)
# Rank number 29: Dark matter gathers around as pot of water and (Mean PMI score: 1.5279240105737046)
# Rank number 30: Dark matter gathers around as pot of people (Mean PMI score: 1.4901243077472237)
# Rank number 31: Dark matter gathers around as pot of water and soap (Mean PMI score: 1.4719501798997892)
# Rank number 32: Dark matter gathers around as pot of water (Mean PMI score: 1.443623759675549)
# Rank number 33: Dark matter gathers around as pot to see a man (Mean PMI score: 1.4289405957746084)
# Rank number 34: Dark matter gathers around as group of (Mean PMI score: 1.4121829639837762)
# Rank number 35: Dark matter gathers around as pot to see the camera (Mean PMI score: 1.4064228083923467)
# Rank number 36: Dark matter gathers around as pot to see if (Mean PMI score: 1.3995093420437386)
# Rank number 37: Dark matter gathers around as pot to boil the camera (Mean PMI score: 1.3744260975157427)
# Rank number 38: Dark matter gathers around as pot to boil water (Mean PMI score: 1.343757271888323)
# Rank number 39: Dark matter gathers around as pot of water to (Mean PMI score: 1.339580170559342)
# Rank number 40: Dark matter gathers around as pot to see the net (Mean PMI score: 1.328663060135594)
# Rank number 41: Dark matter gathers around as (Mean PMI score: 1.2685912934796821)
# Rank number 42: Dark matter gathers around as pot to see the pasta (Mean PMI score: 1.2681064578769927)
# Rank number 43: Dark matter gathers around as pot to boil water to (Mean PMI score: 1.2623703579836087)
# Rank number 44: Dark matter gathers around as pot of (Mean PMI score: 1.2468871943549702)
# Rank number 45: Dark matter gathers around as pot to see the ending (Mean PMI score: 1.246297515828622)
# Rank number 46: Dark matter gathers around as pot of water to the (Mean PMI score: 1.234251693482034)
# Rank number 47: Dark matter gathers around as man standing (Mean PMI score: 1.229406599241207)
# Rank number 48: Dark matter gathers around as pot to boil the water (Mean PMI score: 1.1798977238962522)
# Rank number 49: Dark matter gathers around as pot to see a (Mean PMI score: 1.175940279795907)
# Rank number 50: Dark matter gathers around as pot of water to a (Mean PMI score: 1.1087810263375022)
# Rank number 51: Dark matter gathers around as pot to the camera (Mean PMI score: 1.0976357401023071)
# Rank number 52: Dark matter gathers around as pot to see the (Mean PMI score: 1.084090064203867)
# Rank number 53: Dark matter gathers around as pot to boil the (Mean PMI score: 1.0480937644676878)
# Rank number 54: Dark matter gathers around as man (Mean PMI score: 1.0148730347837458)
# Rank number 55: Dark matter gathers around as pot (Mean PMI score: 1.0148730347837458)
# Rank number 56: Dark matter gathers around as pot to see (Mean PMI score: 0.9875606670487816)
# Rank number 57: Dark matter gathers around as pot to boil (Mean PMI score: 0.9553853735656501)
# Rank number 58: Dark matter gathers around as pot of water <e> formado (Mean PMI score: 0.9186696652480766)
# Rank number 59: Dark matter gathers around as pot to (Mean PMI score: 0.7340628803424506)
# Rank number 60: Dark matter gathers around <e> formado (Mean PMI score: 0.7153317006377987)
# Rank number 61: Dark matter gathers around as pot to the (Mean PMI score: 0.6851430227026106)
# Rank number 62: Dark matter gathers around as group (Mean PMI score: 0.6719471363814554)
# Rank number 63: Dark matter gathers around as pot to boil <e> formado (Mean PMI score: 0.6079725104508683)

# %% [markdown]
# Testing Script

# %%
file_name='/Users/vidurgoel/Desktop/Ml_project/a1.txt'
with open(file_name, 'r') as file:
    lines = [line.strip() for line in file]
print(lines)
for line in lines:
    print("Given line: ",line)
    print()
    sentence_list=sentences_generator(line)
    printing(corpus,sentence_list)
    print()
    print()
    print()
# Out:
# ['A female chef in white uniform shows a stack of baking pans in a large kitchen presenting them. the pans', 'The man in the center is demonstrating a hairstyle on the person wearing the blue shirt. the man in the blue shirt', 'The man in the blue shirt sits on the chair next to the sink. The other man begins washing his hair. he', 'Two bodybuilder women are seated at a table. they', 'Two bodybuilder women are seated at a table. They are arm wrestling, vieing to win. when there', 'This is a tutorial on how to start a campfire. it', 'This is a tutorial on how to start a campfire. It shows the campfire burning on the ground. it', 'It shows the campfire burning on the ground. It starts with the things you will need to begin with. a designated place and some rocks', '.a lady named linda, creator of paint along', 'A lady named linda, creator of paint along is demonstrating how to do an acrylic painting. she']
# Given line:  A female chef in white uniform shows a stack of baking pans in a large kitchen presenting them. the pans
#
# Printing the top ranked sentences according to the Mean PMI scores(sentences ended with <e>):
# Rank number 1: A female chef in white uniform shows a stack of baking pans in a large kitchen presenting them. the pans <e> (Mean PMI score: 2.867985074258998)
#
#
# Printing the top ranked sentences according to the Mean PMI scores(sentences not ended with <e>):
# Rank number 1: A female chef in white uniform shows a stack of baking pans in a large kitchen presenting them. the pans <e> formado sozo appears on (Mean PMI score: 3.834329381801022)
# Rank number 2: A female chef in white uniform shows a stack of baking pans in a large kitchen presenting them. the pans <e> formado sozo appears (Mean PMI score: 3.8220114214038388)
# Rank number 3: A female chef in white uniform shows a stack of baking pans in a large kitchen presenting them. the pans <e> formado sozo appears on the (Mean PMI score: 3.79234034736322)
# Rank number 4: A female chef in white uniform shows a stack of baking pans in a large kitchen presenting them. the pans <e> formado sozo appears on a (Mean PMI score: 3.7733935789518545)
# Rank number 5: A female chef in white uniform shows a stack of baking pans in a large kitchen presenting them. the pans <e> formado sozo (Mean PMI score: 3.4882019025441853)
# Rank number 6: A female chef in white uniform shows a stack of baking pans in a large kitchen presenting them. the pans <e> formado (Mean PMI score: 2.7484856961648734)
#
#
#
# Given line:  The man in the center is demonstrating a hairstyle on the person wearing the blue shirt. the man in the blue shirt
#
# Printing the top ranked sentences according to the Mean PMI scores(sentences ended with <e>):
# Rank number 1: The man in the center is demonstrating a hairstyle on the person wearing the blue shirt. the man in the blue shirt sits on a rowing machine <e> (Mean PMI score: 2.7485355328981464)
# Rank number 2: The man in the center is demonstrating a hairstyle on the person wearing the blue shirt. the man in the blue shirt is practicing shot put it <e> (Mean PMI score: 2.717823962868401)
# Rank number 3: The man in the center is demonstrating a hairstyle on the person wearing the blue shirt. the man in the blue shirt is standing next to him <e> (Mean PMI score: 2.5521337977495757)
# Rank number 4: The man in the center is demonstrating a hairstyle on the person wearing the blue shirt. the man in the blue shirt is practicing shot <e> (Mean PMI score: 2.51739829191508)
# Rank number 5: The man in the center is demonstrating a hairstyle on the person wearing the blue shirt. the man in the blue shirt is standing next to them <e> (Mean PMI score: 2.507596199916736)
# Rank number 6: The man in the center is demonstrating a hairstyle on the person wearing the blue shirt. the man in the blue shirt sits on the camera <e> (Mean PMI score: 2.494970244785362)
# Rank number 7: The man in the center is demonstrating a hairstyle on the person wearing the blue shirt. the man in the blue shirt sits on the ground <e> (Mean PMI score: 2.4901856814885495)
# Rank number 8: The man in the center is demonstrating a hairstyle on the person wearing the blue shirt. the man in the blue shirt sits on a chair <e> (Mean PMI score: 2.4640943860066558)
# Rank number 9: The man in the center is demonstrating a hairstyle on the person wearing the blue shirt. the man in the blue shirt throws the camera <e> (Mean PMI score: 2.4485490691359013)
# Rank number 10: The man in the center is demonstrating a hairstyle on the person wearing the blue shirt. the man in the blue shirt sits on a table <e> (Mean PMI score: 2.4466366471005516)
#
#
# Printing the top ranked sentences according to the Mean PMI scores(sentences not ended with <e>):
# Rank number 1: The man in the center is demonstrating a hairstyle on the person wearing the blue shirt. the man in the blue shirt is practicing shot <e> formado sozo (Mean PMI score: 3.0576181009756644)
# Rank number 2: The man in the center is demonstrating a hairstyle on the person wearing the blue shirt. the man in the blue shirt sits on a rowing machine (Mean PMI score: 3.0539283698868296)
# Rank number 3: The man in the center is demonstrating a hairstyle on the person wearing the blue shirt. the man in the blue shirt throws the ball in slow motion (Mean PMI score: 3.0531493854835445)
# Rank number 4: The man in the center is demonstrating a hairstyle on the person wearing the blue shirt. the man in the blue shirt is practicing shot put in front (Mean PMI score: 3.0488890011503726)
# Rank number 5: The man in the center is demonstrating a hairstyle on the person wearing the blue shirt. the man in the blue shirt is practicing shot put it (Mean PMI score: 3.0198044031871123)
# Rank number 6: The man in the center is demonstrating a hairstyle on the person wearing the blue shirt. the man in the blue shirt is standing next to him observing (Mean PMI score: 3.0174081059188507)
# Rank number 7: The man in the center is demonstrating a hairstyle on the person wearing the blue shirt. the man in the blue shirt is practicing shot put (Mean PMI score: 3.0023454268929797)
# Rank number 8: The man in the center is demonstrating a hairstyle on the person wearing the blue shirt. the man in the blue shirt throws the camera <e> formado sozo (Mean PMI score: 2.993358826381764)
# Rank number 9: The man in the center is demonstrating a hairstyle on the person wearing the blue shirt. the man in the blue shirt is practicing shot put in (Mean PMI score: 2.961905080011631)
# Rank number 10: The man in the center is demonstrating a hairstyle on the person wearing the blue shirt. the man in the blue shirt is standing in front of (Mean PMI score: 2.9562383822427734)
#
#
#
# Given line:  The man in the blue shirt sits on the chair next to the sink. The other man begins washing his hair. he
#
# Printing the top ranked sentences according to the Mean PMI scores(sentences ended with <e>):
# Rank number 1: The man in the blue shirt sits on the chair next to the sink. The other man begins washing his hair. he or you can help them <e> (Mean PMI score: 2.571152330817546)
# Rank number 2: The man in the blue shirt sits on the chair next to the sink. The other man begins washing his hair. he or you can use <e> (Mean PMI score: 2.519057533664601)
#
#
# Printing the top ranked sentences according to the Mean PMI scores(sentences not ended with <e>):
# Rank number 1: The man in the blue shirt sits on the chair next to the sink. The other man begins washing his hair. he or she begins to arm wrestle (Mean PMI score: 3.128971830450837)
# Rank number 2: The man in the blue shirt sits on the chair next to the sink. The other man begins washing his hair. he or she begins to arm wrestling (Mean PMI score: 3.1211205642092525)
# Rank number 3: The man in the blue shirt sits on the chair next to the sink. The other man begins washing his hair. he or she will be able to (Mean PMI score: 3.029426815594255)
# Rank number 4: The man in the blue shirt sits on the chair next to the sink. The other man begins washing his hair. he or you want to make sure (Mean PMI score: 3.0137348757542863)
# Rank number 5: The man in the blue shirt sits on the chair next to the sink. The other man begins washing his hair. he or she will be able (Mean PMI score: 2.9713964411323426)
# Rank number 6: The man in the blue shirt sits on the chair next to the sink. The other man begins washing his hair. he or you can help you want (Mean PMI score: 2.9548337691201083)
# Rank number 7: The man in the blue shirt sits on the chair next to the sink. The other man begins washing his hair. he or you want to build up (Mean PMI score: 2.9411958949987365)
# Rank number 8: The man in the blue shirt sits on the chair next to the sink. The other man begins washing his hair. he or she will need to make (Mean PMI score: 2.907767011758168)
# Rank number 9: The man in the blue shirt sits on the chair next to the sink. The other man begins washing his hair. he or she begins to (Mean PMI score: 2.8987289972667787)
# Rank number 10: The man in the blue shirt sits on the chair next to the sink. The other man begins washing his hair. he or she begins jogging back (Mean PMI score: 2.894465612108229)
#
#
#
# Given line:  Two bodybuilder women are seated at a table. they
#
# Printing the top ranked sentences according to the Mean PMI scores(sentences ended with <e>):
# Rank number 1: Two bodybuilder women are seated at a table. they can also be stubborn wall <e> (Mean PMI score: 3.6419884700639016)
# Rank number 2: Two bodybuilder women are seated at a table. they have a sand castle <e> (Mean PMI score: 3.5104544981256933)
# Rank number 3: Two bodybuilder women are seated at a table. they have been shown <e> (Mean PMI score: 3.4717295025129373)
# Rank number 4: Two bodybuilder women are seated at a table. they can also be used <e> (Mean PMI score: 3.4355448017852104)
# Rank number 5: Two bodybuilder women are seated at a table. they have to duck behind him <e> (Mean PMI score: 3.422132977858383)
# Rank number 6: Two bodybuilder women are seated at a table. they can help you avoid disappointment <e> (Mean PMI score: 3.357602497326976)
# Rank number 7: Two bodybuilder women are seated at a table. they can also use <e> (Mean PMI score: 3.3260752864342362)
# Rank number 8: Two bodybuilder women are seated at a table. they have a big enough house <e> (Mean PMI score: 3.303482587643811)
# Rank number 9: Two bodybuilder women are seated at a table. they can help you avoid foods <e> (Mean PMI score: 3.2935921554807197)
# Rank number 10: Two bodybuilder women are seated at a table. they have to duck behind trees <e> (Mean PMI score: 3.2593831228596493)
#
#
# Printing the top ranked sentences according to the Mean PMI scores(sentences not ended with <e>):
# Rank number 1: Two bodybuilder women are seated at a table. they can also use an electric mixer (Mean PMI score: 4.733366101271561)
# Rank number 2: Two bodybuilder women are seated at a table. they can also be stubborn wall paper (Mean PMI score: 4.595273665467132)
# Rank number 3: Two bodybuilder women are seated at a table. they can also use an empty cubicle (Mean PMI score: 4.578513437397434)
# Rank number 4: Two bodybuilder women are seated at a table. they can also use an electric kettle (Mean PMI score: 4.53675817920504)
# Rank number 5: Two bodybuilder women are seated at a table. they can also use an ice cream (Mean PMI score: 4.428979305663128)
# Rank number 6: Two bodybuilder women are seated at a table. they can also be stubborn wall (Mean PMI score: 4.42241457079188)
# Rank number 7: Two bodybuilder women are seated at a table. they can also use an ice cube (Mean PMI score: 4.405938509656832)
# Rank number 8: Two bodybuilder women are seated at a table. they can also be able to (Mean PMI score: 4.377576506401027)
# Rank number 9: Two bodybuilder women are seated at a table. they can also be able (Mean PMI score: 4.356291829929736)
# Rank number 10: Two bodybuilder women are seated at a table. they have been shown (Mean PMI score: 4.339661878141172)
#
#
#
# Given line:  Two bodybuilder women are seated at a table. They are arm wrestling, vieing to win. when there
#
# Printing the top ranked sentences according to the Mean PMI scores(sentences ended with <e>):
# Rank number 1: Two bodybuilder women are seated at a table. They are arm wrestling, vieing to win. when there is a victor the camera <e> (Mean PMI score: 3.0347156060319085)
# Rank number 2: Two bodybuilder women are seated at a table. They are arm wrestling, vieing to win. when there is a lot of competition <e> (Mean PMI score: 2.9930958528007383)
#
#
# Printing the top ranked sentences according to the Mean PMI scores(sentences not ended with <e>):
# Rank number 1: Two bodybuilder women are seated at a table. They are arm wrestling, vieing to win. when there is standing in front of (Mean PMI score: 3.7599249211491057)
# Rank number 2: Two bodybuilder women are seated at a table. They are arm wrestling, vieing to win. when there is standing in front of people (Mean PMI score: 3.7275098038271715)
# Rank number 3: Two bodybuilder women are seated at a table. They are arm wrestling, vieing to win. when there is a man is seen speaking (Mean PMI score: 3.722642852533769)
# Rank number 4: Two bodybuilder women are seated at a table. They are arm wrestling, vieing to win. when there is standing in front (Mean PMI score: 3.69830030501528)
# Rank number 5: Two bodybuilder women are seated at a table. They are arm wrestling, vieing to win. when there is standing in front of the (Mean PMI score: 3.696069682621448)
# Rank number 6: Two bodybuilder women are seated at a table. They are arm wrestling, vieing to win. when there is a good idea of (Mean PMI score: 3.6578390247126915)
# Rank number 7: Two bodybuilder women are seated at a table. They are arm wrestling, vieing to win. when there is standing in front of a (Mean PMI score: 3.643946837834107)
# Rank number 8: Two bodybuilder women are seated at a table. They are arm wrestling, vieing to win. when there is a good idea (Mean PMI score: 3.643166016139189)
# Rank number 9: Two bodybuilder women are seated at a table. They are arm wrestling, vieing to win. when there is a good idea of people (Mean PMI score: 3.6295073432482137)
# Rank number 10: Two bodybuilder women are seated at a table. They are arm wrestling, vieing to win. when there is standing in (Mean PMI score: 3.6210660065206834)
#
#
#
# Given line:  This is a tutorial on how to start a campfire. it
#
# Printing the top ranked sentences according to the Mean PMI scores(sentences ended with <e>):
# Rank number 1: This is a tutorial on how to start a campfire. it <e> (Mean PMI score: 1.9086645337815704)
#
#
# Printing the top ranked sentences according to the Mean PMI scores(sentences not ended with <e>):
# Rank number 1: This is a tutorial on how to start a campfire. it <e> formado sozo appears on (Mean PMI score: 3.5713633374229232)
# Rank number 2: This is a tutorial on how to start a campfire. it <e> formado sozo appears (Mean PMI score: 3.5370555130285197)
# Rank number 3: This is a tutorial on how to start a campfire. it <e> formado sozo appears on the (Mean PMI score: 3.523325078481852)
# Rank number 4: This is a tutorial on how to start a campfire. it <e> formado sozo appears on a (Mean PMI score: 3.495403525033524)
# Rank number 5: This is a tutorial on how to start a campfire. it <e> formado sozo (Mean PMI score: 2.997668395536854)
# Rank number 6: This is a tutorial on how to start a campfire. it <e> formado (Mean PMI score: 1.7814202315294658)
#
#
#
# Given line:  This is a tutorial on how to start a campfire. It shows the campfire burning on the ground. it
#
# Printing the top ranked sentences according to the Mean PMI scores(sentences ended with <e>):
# Rank number 1: This is a tutorial on how to start a campfire. It shows the campfire burning on the ground. it is standing on the sidelines <e> (Mean PMI score: 2.587420932507325)
# Rank number 2: This is a tutorial on how to start a campfire. It shows the campfire burning on the ground. it is standing on the camera <e> (Mean PMI score: 2.580339409233396)
# Rank number 3: This is a tutorial on how to start a campfire. It shows the campfire burning on the ground. it is standing on the ground <e> (Mean PMI score: 2.575383968675983)
# Rank number 4: This is a tutorial on how to start a campfire. It shows the campfire burning on the ground. it is standing on the sidewalk <e> (Mean PMI score: 2.5594923843722994)
# Rank number 5: This is a tutorial on how to start a campfire. It shows the campfire burning on the ground. it is standing on a table <e> (Mean PMI score: 2.530279611631271)
# Rank number 6: This is a tutorial on how to start a campfire. It shows the campfire burning on the ground. it is recommended that you use <e> (Mean PMI score: 2.4926648189587644)
# Rank number 7: This is a tutorial on how to start a campfire. It shows the campfire burning on the ground. it <e> (Mean PMI score: 2.314751313187864)
#
#
# Printing the top ranked sentences according to the Mean PMI scores(sentences not ended with <e>):
# Rank number 1: This is a tutorial on how to start a campfire. It shows the campfire burning on the ground. it <e> formado sozo appears on (Mean PMI score: 3.3630561779256114)
# Rank number 2: This is a tutorial on how to start a campfire. It shows the campfire burning on the ground. it <e> formado sozo appears on the (Mean PMI score: 3.337898329340503)
# Rank number 3: This is a tutorial on how to start a campfire. It shows the campfire burning on the ground. it <e> formado sozo appears (Mean PMI score: 3.3326123250716817)
# Rank number 4: This is a tutorial on how to start a campfire. It shows the campfire burning on the ground. it <e> formado sozo appears on a (Mean PMI score: 3.318951560929137)
# Rank number 5: This is a tutorial on how to start a campfire. It shows the campfire burning on the ground. it is standing on a tennis racket (Mean PMI score: 3.1871375491906684)
# Rank number 6: This is a tutorial on how to start a campfire. It shows the campfire burning on the ground. it is standing on a basketball court (Mean PMI score: 3.0962498911884655)
# Rank number 7: This is a tutorial on how to start a campfire. It shows the campfire burning on the ground. it is standing on a tennis court (Mean PMI score: 3.09012658793899)
# Rank number 8: This is a tutorial on how to start a campfire. It shows the campfire burning on the ground. it is standing in front of (Mean PMI score: 3.057393835134381)
# Rank number 9: This is a tutorial on how to start a campfire. It shows the campfire burning on the ground. it is standing in front of people (Mean PMI score: 3.0532458794792414)
# Rank number 10: This is a tutorial on how to start a campfire. It shows the campfire burning on the ground. it is standing in front of the (Mean PMI score: 3.023014993704507)
#
#
#
# Given line:  It shows the campfire burning on the ground. It starts with the things you will need to begin with. a designated place and some rocks
#
# Printing the top ranked sentences according to the Mean PMI scores(sentences ended with <e>):
# Rank number 1: It shows the campfire burning on the ground. It starts with the things you will need to begin with. a designated place and some rocks paper towel <e> (Mean PMI score: 2.4193027735014896)
# Rank number 2: It shows the campfire burning on the ground. It starts with the things you will need to begin with. a designated place and some rocks paper scissors <e> (Mean PMI score: 2.3938434341428554)
# Rank number 3: It shows the campfire burning on the ground. It starts with the things you will need to begin with. a designated place and some rocks paper scissors and the camera <e> (Mean PMI score: 2.384645279402659)
#
#
# Printing the top ranked sentences according to the Mean PMI scores(sentences not ended with <e>):
# Rank number 1: It shows the campfire burning on the ground. It starts with the things you will need to begin with. a designated place and some rocks paper towel <e> formado sozo appears (Mean PMI score: 3.18844194785556)
# Rank number 2: It shows the campfire burning on the ground. It starts with the things you will need to begin with. a designated place and some rocks paper scissors <e> formado sozo appears (Mean PMI score: 3.1652290207932756)
# Rank number 3: It shows the campfire burning on the ground. It starts with the things you will need to begin with. a designated place and some rocks paper towel <e> formado sozo (Mean PMI score: 2.9163568737634504)
# Rank number 4: It shows the campfire burning on the ground. It starts with the things you will need to begin with. a designated place and some rocks paper scissors and leads into (Mean PMI score: 2.9031357443627956)
# Rank number 5: It shows the campfire burning on the ground. It starts with the things you will need to begin with. a designated place and some rocks paper scissors and leads into the (Mean PMI score: 2.893558042202187)
# Rank number 6: It shows the campfire burning on the ground. It starts with the things you will need to begin with. a designated place and some rocks paper scissors <e> formado sozo (Mean PMI score: 2.892440524668976)
# Rank number 7: It shows the campfire burning on the ground. It starts with the things you will need to begin with. a designated place and some rocks paper scissors and the losers gets (Mean PMI score: 2.8715080120915153)
# Rank number 8: It shows the campfire burning on the ground. It starts with the things you will need to begin with. a designated place and some rocks paper scissors and the camera pans (Mean PMI score: 2.8127716882205847)
# Rank number 9: It shows the campfire burning on the ground. It starts with the things you will need to begin with. a designated place and some rocks paper scissors and leads into young (Mean PMI score: 2.795330215140455)
# Rank number 10: It shows the campfire burning on the ground. It starts with the things you will need to begin with. a designated place and some rocks paper scissors and leads (Mean PMI score: 2.7282531119713074)
#
#
#
# Given line:  .a lady named linda, creator of paint along
#
# Printing the top ranked sentences according to the Mean PMI scores(sentences ended with <e>):
# Rank number 1: .a lady named linda, creator of paint along is demonstrating how to use <e> (Mean PMI score: 3.098304230084988)
# Rank number 2: .a lady named linda, creator of paint along the camera <e> (Mean PMI score: 3.071735062306023)
# Rank number 3: .a lady named linda, creator of paint along the water <e> (Mean PMI score: 2.9370615728771443)
# Rank number 4: .a lady named linda, creator of paint along the way to do so <e> (Mean PMI score: 2.9359722704231936)
# Rank number 5: .a lady named linda, creator of paint along the way to the camera <e> (Mean PMI score: 2.840434048854897)
#
#
# Printing the top ranked sentences according to the Mean PMI scores(sentences not ended with <e>):
# Rank number 1: .a lady named linda, creator of paint along the camera <e> formado sozo appears (Mean PMI score: 4.583824753657572)
# Rank number 2: .a lady named linda, creator of paint along the water <e> formado sozo appears (Mean PMI score: 4.474402543496608)
# Rank number 3: .a lady named linda, creator of paint along is demonstrating how to make sure (Mean PMI score: 4.145622517110303)
# Rank number 4: .a lady named linda, creator of paint along the camera <e> formado sozo (Mean PMI score: 4.078263111041732)
# Rank number 5: .a lady named linda, creator of paint along the (Mean PMI score: 3.9941634497864573)
# Rank number 6: .a lady named linda, creator of paint along the camera (Mean PMI score: 3.99325558099783)
# Rank number 7: .a lady named linda, creator of paint along is standing in front of (Mean PMI score: 3.991387233226967)
# Rank number 8: .a lady named linda, creator of paint along the water <e> formado sozo (Mean PMI score: 3.961546086870037)
# Rank number 9: .a lady named linda, creator of paint along is standing in front of people (Mean PMI score: 3.916970072860809)
# Rank number 10: .a lady named linda, creator of paint along is demonstrating how to (Mean PMI score: 3.904839452825407)
#
#
#
# Given line:  A lady named linda, creator of paint along is demonstrating how to do an acrylic painting. she
#
# Printing the top ranked sentences according to the Mean PMI scores(sentences ended with <e>):
# Rank number 1: A lady named linda, creator of paint along is demonstrating how to do an acrylic painting. she begins to arm wrestling match <e> (Mean PMI score: 3.8503050706363138)
# Rank number 2: A lady named linda, creator of paint along is demonstrating how to do an acrylic painting. she begins to arm wrestle <e> (Mean PMI score: 3.5830410853427277)
# Rank number 3: A lady named linda, creator of paint along is demonstrating how to do an acrylic painting. she begins jogging back and forth <e> (Mean PMI score: 3.383262844020962)
# Rank number 4: A lady named linda, creator of paint along is demonstrating how to do an acrylic painting. she begins to the camera <e> (Mean PMI score: 3.259129424618428)
#
#
# Printing the top ranked sentences according to the Mean PMI scores(sentences not ended with <e>):
# Rank number 1: A lady named linda, creator of paint along is demonstrating how to do an acrylic painting. she begins to arm wrestling match (Mean PMI score: 4.3525187755019195)
# Rank number 2: A lady named linda, creator of paint along is demonstrating how to do an acrylic painting. she begins to arm wrestle (Mean PMI score: 4.071637596980373)
# Rank number 3: A lady named linda, creator of paint along is demonstrating how to do an acrylic painting. she begins to arm wrestling (Mean PMI score: 4.061288200571011)
# Rank number 4: A lady named linda, creator of paint along is demonstrating how to do an acrylic painting. she begins jogging back and leads into (Mean PMI score: 3.9751945277563334)
# Rank number 5: A lady named linda, creator of paint along is demonstrating how to do an acrylic painting. she begins (Mean PMI score: 3.889537789325399)
# Rank number 6: A lady named linda, creator of paint along is demonstrating how to do an acrylic painting. she begins to (Mean PMI score: 3.855076348834847)
# Rank number 7: A lady named linda, creator of paint along is demonstrating how to do an acrylic painting. she begins jogging back and forth (Mean PMI score: 3.8245579975889132)
# Rank number 8: A lady named linda, creator of paint along is demonstrating how to do an acrylic painting. she begins jogging back (Mean PMI score: 3.803851485215444)
# Rank number 9: A lady named linda, creator of paint along is demonstrating how to do an acrylic painting. she begins jogging back and leads (Mean PMI score: 3.793697997828025)
# Rank number 10: A lady named linda, creator of paint along is demonstrating how to do an acrylic painting. she begins jogging back and (Mean PMI score: 3.7606572341700333)
